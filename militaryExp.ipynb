# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
Military=pd.read_csv('/home/ram/MilitaryExpenditure.csv')
print(Military)
# Out:
#              Name Code     Type                      Indicator Name  \
# 0           Aruba  ABW  Country  Military expenditure (current USD)
# 1     Afghanistan  AFG  Country  Military expenditure (current USD)
# 2          Angola  AGO  Country  Military expenditure (current USD)
# 3         Albania  ALB  Country  Military expenditure (current USD)
# 4         Andorra  AND  Country  Military expenditure (current USD)
# ..            ...  ...      ...                                 ...
# 259        Kosovo  XKX  Country  Military expenditure (current USD)
# 260   Yemen, Rep.  YEM  Country  Military expenditure (current USD)
# 261  South Africa  ZAF  Country  Military expenditure (current USD)
# 262        Zambia  ZMB  Country  Military expenditure (current USD)
# 263      Zimbabwe  ZWE  Country  Military expenditure (current USD)
#
#            1960         1961         1962         1963         1964  \
# 0           NaN          NaN          NaN          NaN          NaN
# ...

# %%
Military.head()
# Out:
#           Name Code     Type                      Indicator Name  1960  1961  \
# 0        Aruba  ABW  Country  Military expenditure (current USD)   NaN   NaN
# 1  Afghanistan  AFG  Country  Military expenditure (current USD)   NaN   NaN
# 2       Angola  AGO  Country  Military expenditure (current USD)   NaN   NaN
# 3      Albania  ALB  Country  Military expenditure (current USD)   NaN   NaN
# 4      Andorra  AND  Country  Military expenditure (current USD)   NaN   NaN
#
#    1962  1963  1964  1965  ...          2009          2010          2011  \
# 0   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
# 1   NaN   NaN   NaN   NaN  ...  2.518695e+08  2.981469e+08  3.258070e+08
# 2   NaN   NaN   NaN   NaN  ...  3.311193e+09  3.500795e+09  3.639496e+09
# 3   NaN   NaN   NaN   NaN  ...  1.827369e+08  1.858932e+08  1.970068e+08
# 4   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
#
# ...

# %%
Military.tail()
# Out:
#              Name Code     Type                      Indicator Name  \
# 259        Kosovo  XKX  Country  Military expenditure (current USD)
# 260   Yemen, Rep.  YEM  Country  Military expenditure (current USD)
# 261  South Africa  ZAF  Country  Military expenditure (current USD)
# 262        Zambia  ZMB  Country  Military expenditure (current USD)
# 263      Zimbabwe  ZWE  Country  Military expenditure (current USD)
#
#            1960         1961         1962         1963         1964  \
# 259         NaN          NaN          NaN          NaN          NaN
# 260         NaN          NaN          NaN          NaN          NaN
# 261  69999972.0  113749954.5  186199925.5  188999924.4  271599891.4
# 262         NaN          NaN          NaN          NaN          NaN
# 263         NaN          NaN          NaN          NaN          NaN
#
#             1965  ...          2009          2010          2011          2012  \
# ...

# %%
Military.to_numpy()
# Out:
# array([['Aruba', 'ABW', 'Country', ..., nan, nan, nan],
#        ['Afghanistan', 'AFG', 'Country', ..., 185878310.1, 191407113.2,
#         198086263.3],
#        ['Angola', 'AGO', 'Country', ..., 2764054937.0, 3062872914.0,
#         1983613748.0],
#        ...,
#        ['South Africa', 'ZAF', 'Country', ..., 3169756001.0,
#         3638936588.0, 3639879165.0],
#        ['Zambia', 'ZMB', 'Country', ..., 299504759.9, 339664531.4,
#         378025431.0],
#        ['Zimbabwe', 'ZWE', 'Country', ..., 358065000.0, 340522000.0,
#         420364000.0]], dtype=object)

# %%
Military.describe()
# Out:
#                1960          1961          1962          1963          1964  \
# count  7.900000e+01  8.400000e+01  9.300000e+01  9.800000e+01  9.800000e+01
# mean   4.482374e+09  4.450649e+09  4.520297e+09  4.462435e+09  4.525730e+09
# std    1.447959e+10  1.486998e+10  1.560037e+10  1.551553e+10  1.552208e+10
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    3.205030e+07  2.571702e+07  2.484204e+07  2.866130e+07  3.662134e+07
# 50%    1.408889e+08  1.200573e+08  1.700342e+08  1.824402e+08  1.891038e+08
# 75%    8.240486e+08  7.590874e+08  8.332295e+08  8.987564e+08  1.144744e+09
# max    6.777699e+10  7.161496e+10  7.889139e+10  8.097281e+10  8.148150e+10
#
#                1965          1966          1967          1968          1969  \
# count  1.040000e+02  1.040000e+02  1.050000e+02  1.130000e+02  1.130000e+02
# mean   4.429380e+09  5.098436e+09  5.757744e+09  5.661456e+09  5.866198e+09
# ...

# %%
Military.sort_index(axis='columns',ascending=False)
# Out:
#         Type          Name                      Indicator Name Code  \
# 0    Country         Aruba  Military expenditure (current USD)  ABW
# 1    Country   Afghanistan  Military expenditure (current USD)  AFG
# 2    Country        Angola  Military expenditure (current USD)  AGO
# 3    Country       Albania  Military expenditure (current USD)  ALB
# 4    Country       Andorra  Military expenditure (current USD)  AND
# ..       ...           ...                                 ...  ...
# 259  Country        Kosovo  Military expenditure (current USD)  XKX
# 260  Country   Yemen, Rep.  Military expenditure (current USD)  YEM
# 261  Country  South Africa  Military expenditure (current USD)  ZAF
# 262  Country        Zambia  Military expenditure (current USD)  ZMB
# 263  Country      Zimbabwe  Military expenditure (current USD)  ZWE
#
#              2018          2017          2016          2015          2014  \
# 0             NaN           NaN           NaN           NaN           NaN
# ...

# %%
Military.Name.value_counts()
# Out:
# French Polynesia                                 1
# Fiji                                             1
# Botswana                                         1
# Bangladesh                                       1
# Liechtenstein                                    1
#                                                 ..
# Somalia                                          1
# Europe & Central Asia (excluding high income)    1
# Zambia                                           1
# Moldova                                          1
# United Arab Emirates                             1
# Name: Name, Length: 264, dtype: int64

# %%
Military.index
Military.columns
# Out:
# Index(['Name', 'Code', 'Type', 'Indicator Name', '1960', '1961', '1962',
#        '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971',
#        '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980',
#        '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#        '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#        '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#        '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#        '2017', '2018'],
#       dtype='object')

# %%
Military.dtypes
# Out:
# Name               object
# Code               object
# Type               object
# Indicator Name     object
# 1960              float64
#                    ...
# 2014              float64
# 2015              float64
# 2016              float64
# 2017              float64
# 2018              float64
# Length: 63, dtype: object

# %%
Military.axes
# Out:
# [RangeIndex(start=0, stop=264, step=1),
#  Index(['Name', 'Code', 'Type', 'Indicator Name', '1960', '1961', '1962',
#         '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971',
#         '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980',
#         '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989',
#         '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
#         '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007',
#         '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016',
#         '2017', '2018'],
#        dtype='object')]

# %%
Military.ndim
# Out:
# 2

# %%
Military.size
# Out:
# 16632

# %%
Military.shape
# Out:
# (264, 63)

# %%
Military.empty
# Out:
# False

# %%
Military.loc[4].at['Name']
# Out:
# 'Andorra'

# %%
Military.at[4,'Name']
# Out:
# 'Andorra'

# %%
Military.infer_objects()
# Out:
#              Name Code     Type                      Indicator Name  \
# 0           Aruba  ABW  Country  Military expenditure (current USD)
# 1     Afghanistan  AFG  Country  Military expenditure (current USD)
# 2          Angola  AGO  Country  Military expenditure (current USD)
# 3         Albania  ALB  Country  Military expenditure (current USD)
# 4         Andorra  AND  Country  Military expenditure (current USD)
# ..            ...  ...      ...                                 ...
# 259        Kosovo  XKX  Country  Military expenditure (current USD)
# 260   Yemen, Rep.  YEM  Country  Military expenditure (current USD)
# 261  South Africa  ZAF  Country  Military expenditure (current USD)
# 262        Zambia  ZMB  Country  Military expenditure (current USD)
# 263      Zimbabwe  ZWE  Country  Military expenditure (current USD)
#
#            1960         1961         1962         1963         1964  \
# 0           NaN          NaN          NaN          NaN          NaN
# ...

# %%
Military.hist(bins=5)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f85d7c41950>,
# ...
#       dtype=object)

# %%
Military.head()
# Out:
#           Name Code     Type                      Indicator Name  1960  1961  \
# 0        Aruba  ABW  Country  Military expenditure (current USD)   NaN   NaN
# 1  Afghanistan  AFG  Country  Military expenditure (current USD)   NaN   NaN
# 2       Angola  AGO  Country  Military expenditure (current USD)   NaN   NaN
# 3      Albania  ALB  Country  Military expenditure (current USD)   NaN   NaN
# 4      Andorra  AND  Country  Military expenditure (current USD)   NaN   NaN
#
#    1962  1963  1964  1965  ...          2009          2010          2011  \
# 0   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
# 1   NaN   NaN   NaN   NaN  ...  2.518695e+08  2.981469e+08  3.258070e+08
# 2   NaN   NaN   NaN   NaN  ...  3.311193e+09  3.500795e+09  3.639496e+09
# 3   NaN   NaN   NaN   NaN  ...  1.827369e+08  1.858932e+08  1.970068e+08
# 4   NaN   NaN   NaN   NaN  ...           NaN           NaN           NaN
#
# ...

# %%
Military.plot.hist(x='2000',y='2012')

# %%
Military.plot.scatter(x='2000',y='2012')

# %%
twok=Military['2000']
twoktwelve=Military['2012']
x=[]
y=[]
x=list(twok)
y=list(twoktwelve)
plt.plot(x,y)
plt.title('Military Expenditure')
plt.xlabel('Year 2000')
plt.ylabel('Year 2012')
# Out:
# Text(0, 0.5, 'Year 2012')

# %%
Military.plot(kind="kde")

# %%
MilitaryMilitary.boxplot()

# %%
data=np.arange(12).reshape(4,3)
df=pd.DataFrame(data,index=['1','2','3','4'],columns=['x','y','z'])
df.plot(kind='kde')
